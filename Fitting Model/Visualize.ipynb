# %%
#All imports 
import os
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import random

# %%
def visualize_images(folder_path, num_images_to_display):

    image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    print(f'Total files in folder {len(image_files)}')
    random_images = random.sample(image_files, num_images_to_display)
    rows = 1
    cols = num_images_to_display
    fig, axes = plt.subplots(rows, cols, figsize=(15, 5))
    for i, image_file in enumerate(random_images):
        img = mpimg.imread(os.path.join(folder_path, image_file))
        ax = axes[i]
        ax.imshow(img)
        ax.axis('off')

    plt.show()

# %% [markdown]
# Image Folder

# %%
visualize_images('/Users/alijohnnaqvi/Desktop/Fall23/DeepLearning/WearVision/Data/zalando-hd-resized/train/image',10)
# Out:
# Total files in folder 11647

# %% [markdown]
# Cloth folder

# %%
visualize_images('/Users/alijohnnaqvi/Desktop/Fall23/DeepLearning/WearVision/Data/zalando-hd-resized/train/cloth',10)
# Out:
# Total files in folder 11647

# %% [markdown]
# Cloth-Mask folder

# %%
visualize_images('/Users/alijohnnaqvi/Desktop/Fall23/DeepLearning/WearVision/Data/zalando-hd-resized/train/cloth-mask',10)
# Out:
# Total files in folder 11647

# %% [markdown]
# Openpose of image

# %%
visualize_images('/Users/alijohnnaqvi/Desktop/Fall23/DeepLearning/WearVision/Data/zalando-hd-resized/train/openpose_img',10)
# Out:
# Total files in folder 11647

# %% [markdown]
# DensePose of Image

# %%
visualize_images('/Users/alijohnnaqvi/Desktop/Fall23/DeepLearning/WearVision/Data/zalando-hd-resized/train/image-densepose',10)
# Out:
# Total files in folder 11647

# %% [markdown]
# Image-Parse-Agnostic

# %%
visualize_images('/Users/alijohnnaqvi/Desktop/Fall23/DeepLearning/WearVision/Data/zalando-hd-resized/train/image-parse-agnostic-v3.2',10)
# Out:
# Total files in folder 11647

# %% [markdown]
# ## Observations about dataset

# %% [markdown]
# - It contain equal number of samples in each folder i.e 11647
# - There are some missing numbering in data. The last sample number in data is 14684 but in total we have 11647 samples because some numbers are missing in between.
# - For example, sample number 6 is not in data
